# %%
import networkx as nx

# Read the graph from the text file
def read_graph(file_path):
    G = nx.DiGraph()
    with open(file_path, 'r') as file:
        for line in file:
            if line.startswith("#"):
                continue
            else:
                edge = line.strip().split()
                if len(edge) == 2:
                    from_node, to_node = map(int, edge)
                    G.add_edge(from_node, to_node)
    return G

# Function to perform PageRank analysis
def page_rank_analysis(graph):
    # Calculate PageRank
    pagerank_scores = nx.pagerank(graph)
    # Sort nodes by PageRank score
    sorted_nodes = sorted(pagerank_scores.items(), key=lambda x: x[1], reverse=True)
    return sorted_nodes

# Path to the text file containing the graph data
file_path = 'Wiki-Vote.txt'

# Read the graph from the text file
graph = read_graph(file_path)

# Perform PageRank analysis
pagerank_result = page_rank_analysis(graph)

# Print the top nodes and their PageRank scores
top_nodes_count = 69
print(f"Top {top_nodes_count} nodes by PageRank:")
for i in range(top_nodes_count):
    node, score = pagerank_result[i]
    print(f"Node {node}: PageRank Score = {score}")
# Out:
# Top 69 nodes by PageRank:
# Node 4037: PageRank Score = 0.004612715891167545
# Node 15: PageRank Score = 0.0036812207295292714
# Node 6634: PageRank Score = 0.003524813657640258
# Node 2625: PageRank Score = 0.0032863743692308997
# Node 2398: PageRank Score = 0.002605333171725021
# Node 2470: PageRank Score = 0.0025301053283849502
# Node 2237: PageRank Score = 0.002504703800483991
# Node 4191: PageRank Score = 0.0022662633042363433
# Node 7553: PageRank Score = 0.0021701850491959583
# Node 5254: PageRank Score = 0.0021500675059293226
# Node 1186: PageRank Score = 0.0020438936876029136
# Node 2328: PageRank Score = 0.0020416288860889173
# Node 1297: PageRank Score = 0.001951860821612229
# Node 4335: PageRank Score = 0.0019353014475784864
# Node 7620: PageRank Score = 0.0019301193957548775
# Node 5412: PageRank Score = 0.0019167080775239903
# Node 7632: PageRank Score = 0.0019037739909136611
# Node 4875: PageRank Score = 0.0018675748225119072
# Node 3352: PageRank Score = 0.0017851250122027217
# Node 2654: PageRank Score = 0.001769320714348241
# Node 6832: PageRank Score = 0.0017646895191923723
# Node 762: PageRank Score = 0.0017478626294191988
# Node 6946: PageRank Score = 0.0017404328450373549
# Node 737: PageRank Score = 0.0017365555312247151
# Node 2066: PageRank Score = 0.0017190133175865345
# Node 8293: PageRank Score = 0.0017044691035007064
# Node 3089: PageRank Score = 0.0016993720805897228
# Node 28: PageRank Score = 0.0016986730322136935
# Node 2535: PageRank Score = 0.0016682067978015195
# Node 214: PageRank Score = 0.0016599199669365457
# Node 3334: PageRank Score = 0.0016535779185613182
# Node 665: PageRank Score = 0.0016523142774243057
# Node 4735: PageRank Score = 0.0016209567580411316
# Node 6774: PageRank Score = 0.001615901009929993
# Node 7092: PageRank Score = 0.001597387253434404
# Node 2565: PageRank Score = 0.0015503503379620098
# Node 5484: PageRank Score = 0.0015430456206335548
# Node 4310: PageRank Score = 0.0014598839350747042
# Node 1211: PageRank Score = 0.0014177146901320054
# Node 5423: PageRank Score = 0.0014139627646056576
# Node 3456: PageRank Score = 0.0014108878727557004
# Node 8042: PageRank Score = 0.001408019073042443
# Node 2657: PageRank Score = 0.0013631759714335006
# Node 5233: PageRank Score = 0.001357976923532472
# Node 5404: PageRank Score = 0.001357657455276512
# Node 271: PageRank Score = 0.0013349240914416604
# Node 4712: PageRank Score = 0.0013347959975447956
# Node 5079: PageRank Score = 0.0012961508663821581
# Node 4828: PageRank Score = 0.001295652931927357
# Node 4261: PageRank Score = 0.0012876727534924758
# Node 5210: PageRank Score = 0.0012812378374335918
# Node 6914: PageRank Score = 0.0012617583332444008
# Node 3459: PageRank Score = 0.001254456521317543
# Node 2285: PageRank Score = 0.0012443777169158046
# Node 1549: PageRank Score = 0.0012421979673656227
# Node 1842: PageRank Score = 0.0012397030472697543
# Node 4666: PageRank Score = 0.0012102604198827058
# Node 993: PageRank Score = 0.0012035351707928498
# Node 8163: PageRank Score = 0.0011948936565061821
# Node 3562: PageRank Score = 0.0011818300897048903
# Node 3084: PageRank Score = 0.0011782972236993026
# Node 1026: PageRank Score = 0.001175321411285121
# Node 5123: PageRank Score = 0.0011612834308386253
# Node 2958: PageRank Score = 0.001158896046276573
# Node 3117: PageRank Score = 0.0011452508166489293
# Node 3537: PageRank Score = 0.001143441013542154
# Node 2576: PageRank Score = 0.0011406284132013619
# Node 2643: PageRank Score = 0.0011230140418049847
# Node 299: PageRank Score = 0.001111572236198922
